# %%
# %run ./1_create_dataset.ipynb

# %%
# %run ./2_dataset_analysis.ipynb
# Out:
# Mean Z-score for pit laps:              0.9524431701979961
# Mean Z-score for non-pit laps:          -0.10412692549829372
#
#
#
# Hungaroring          5403                 Melbourne            2923
# Catalunya            5047                 Baku                 2775
# Zandvoort            4918                 Suzuka               2766
# Sakhir               4384                 Silverstone          2585
# Monte Carlo          4236                 Imola                2335
# Montreal             4083                 Miami                2142
# Monza                3873                 Las Vegas            1827
# Singapore            3804                 Spa-Francorchamps    1631
# Mexico City          3803                 Spielberg            1124
# Jeddah               3377                 Paul Ricard          951
# Yas Marina Circuit   3360                 Austin               914

# %%
# %run ./3_model_selection.ipynb
# Out:
# Sakhir 27
# Jeddah 27
# Melbourne 27
# Miami 27
# Catalunya 27
# Monte Carlo 27
# Baku 27
# Montreal 27
# Silverstone 27
# Paul Ricard 27
# Hungaroring 27
# Spa-Francorchamps 27
# Zandvoort 27
# Monza 27
# Singapore 27
# Suzuka 27
# Austin 27
# Mexico City 27
# Yas Marina Circuit 27
# Las Vegas 27
# Imola 27
# Spielberg 27
# 1. Sakhir
# Fitting LinearRegression...                       Took 0.16 seconds.
# Best score: 0.05181
#
# Fitting RidgeCV...                                Took 0.19 seconds.
# Best score: 0.05188
#
# Fitting LassoCV...                                Took 0.25 seconds.
# Best score: 0.05378
#
# Fitting ElasticNetCV...                           Took 1.65 seconds.
# Best score: 0.05453
#
# Fitting PolynomialLinearRegression...             Took 1.87 seconds.
# Best score: 0.10394
#
# Fitting PolynomialRidgeCV...                      Took 3.32 seconds.
# Best score: 0.1307
#
# Fitting PolynomialLassoCV...                      Took 4.88 seconds.
# Best score: 0.1372
# ...

# %%
# %run ./4_simulation.ipynb

# %%
import pandas as pd

# %%
pd.DataFrame({
    "Monte": 1,
    "Monza": 2
}, index=[0]).T
# Out:
#        0
# Monte  1
# Monza  2
